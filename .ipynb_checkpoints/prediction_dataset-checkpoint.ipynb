# %%
import pandas as pd
from pandas.io.json import json_normalize

# %% [markdown]
# ### Reading Data From Binance
# 🔗 Source: https://binance-docs.github.io/apidocs/spot/en/#kline-candlestick-data
#
# Getting M5 and M1 to DataFrame

# %%
url_binance_bnbusdt_5m = "https://api.binance.com/api/v3/klines?symbol=BNBUSDT&limit=1000&interval=5m"
df_binance_bnbusdt_5m = pd.read_json(url_binance_bnbusdt_5m)

df_binance_bnbusdt_5m.columns = [
    '5m_open_time', 
    '5m_open_price', 
    '5m_high_price', 
    '5m_low_price', 
    '5m_close_price', 
    '5m_volume', 
    '5m_close_time', 
    '5m_quote_asset_volume', 
    '5m_number_of_trades', 
    '5m_taker_buy_base_asset_volume', 
    '5m_taker_buy_quote_asset_volume', 
    '5m_unused'
]

df_binance_bnbusdt_5m
# Out:
#       5m_open_time  5m_open_price  5m_high_price  5m_low_price  \
# 0    1665180900000          282.8          283.1         282.7
# 1    1665181200000          283.0          283.0         282.8
# 2    1665181500000          282.9          283.1         282.9
# 3    1665181800000          283.0          283.0         282.6
# 4    1665182100000          283.0          283.0         282.9
# ..             ...            ...            ...           ...
# 995  1665479400000          271.2          271.5         271.2
# 996  1665479700000          271.4          271.4         271.2
# 997  1665480000000          271.3          271.4         271.1
# 998  1665480300000          271.3          271.3         271.1
# 999  1665480600000          271.1          271.2         271.1
#
#      5m_close_price  5m_volume  5m_close_time  5m_quote_asset_volume  \
# 0             283.0    494.876  1665181199999            139990.3954
# 1             282.9    332.464  1665181499999             94055.5657
# 2             283.0    449.398  1665181799999            127208.4404
# 3             283.0    440.907  1665182099999            124694.9276
# 4             283.0     63.196  1665182399999             17881.8360
# ..              ...        ...            ...                    ...
# 995           271.3   1249.660  1665479699999            339137.5645
# 996           271.2    399.490  1665479999999            108388.0791
# 997           271.3    434.822  1665480299999            117934.2470
# 998           271.2    144.178  1665480599999             39098.4342
# 999           271.2    171.272  1665480899999             46443.5707
#
#      5m_number_of_trades  5m_taker_buy_base_asset_volume  \
# 0                    256                         369.934
# 1                    239                          89.685
# 2                    263                         353.039
# 3                    354                         207.919
# 4                    199                          36.876
# ..                   ...                             ...
# 995                  509                         897.984
# 996                  433                         222.942
# 997                  459                         161.427
# 998                  292                          59.500
# 999                  150                         117.315
#
#      5m_taker_buy_quote_asset_volume  5m_unused
# 0                        104637.5292          0
# 1                         25374.8228          0
# 2                         99939.0818          0
# 3                         58813.9208          0
# 4                         10435.9080          0
# ..                               ...        ...
# 995                      243713.6230          0
# 996                       60497.8585          0
# 997                       43786.8947          0
# 998                       16139.0834          0
# 999                       31815.8280          0
#
# [1000 rows x 12 columns]

# %%
url_binance_bnbusdt_1m = "https://api.binance.com/api/v3/klines?symbol=BNBUSDT&limit=1000&interval=1m"
df_binance_bnbusdt_1m = pd.read_json(url_binance_bnbusdt_1m)

df_binance_bnbusdt_1m.columns = [
    '1m_open_time', 
    '1m_open_price', 
    '1m_high_price', 
    '1m_low_price', 
    '1m_close_price', 
    '1m_volume', 
    '1m_close_time', 
    '1m_quote_asset_volume', 
    '1m_number_of_trades', 
    '1m_taker_buy_base_asset_volume', 
    '1m_taker_buy_quote_asset_volume', 
    '1m_unused'
]

df_binance_bnbusdt_1m
# Out:
#       1m_open_time  1m_open_price  1m_high_price  1m_low_price  \
# 0    1665420900000          273.4          273.6         273.4
# 1    1665420960000          273.6          273.7         273.5
# 2    1665421020000          273.5          273.5         273.3
# 3    1665421080000          273.3          273.5         273.3
# 4    1665421140000          273.3          273.4         273.2
# ..             ...            ...            ...           ...
# 995  1665480600000          271.1          271.2         271.1
# 996  1665480660000          271.2          271.2         271.1
# 997  1665480720000          271.2          271.2         271.1
# 998  1665480780000          271.1          271.2         271.1
# 999  1665480840000          271.2          271.2         271.1
#
#      1m_close_price  1m_volume  1m_close_time  1m_quote_asset_volume  \
# 0             273.5    137.098  1665420959999             37492.8067
# 1             273.5     45.365  1665421019999             12410.8135
# 2             273.3    126.189  1665421079999             34494.6762
# 3             273.4    119.645  1665421139999             32705.5056
# 4             273.2     85.858  1665421199999             23469.1520
# ..              ...        ...            ...                    ...
# 995           271.2     85.172  1665480659999             23094.8885
# 996           271.1     35.435  1665480719999              9608.3427
# 997           271.1     74.242  1665480779999             20133.6545
# 998           271.2     25.658  1665480839999              6957.5553
# 999           271.1     43.427  1665480899999             11773.3231
#
#      1m_number_of_trades  1m_taker_buy_base_asset_volume  \
# 0                    118                         100.715
# 1                     70                          22.766
# 2                     73                          13.076
# 3                    106                          32.879
# 4                     79                          49.537
# ..                   ...                             ...
# 995                   61                          47.593
# 996                   72                          19.142
# 997                   58                          66.483
# 998                   60                          16.715
# 999                   30                           2.634
#
#      1m_taker_buy_quote_asset_volume  1m_unused
# 0                         27545.6083          0
# 1                          6228.8053          0
# 2                          3575.3229          0
# 3                          8989.4598          0
# 4                         13543.0563          0
# ..                               ...        ...
# 995                       12907.2216          0
# 996                        5191.3104          0
# 997                       18030.1896          0
# 998                        4533.1080          0
# 999                         714.3408          0
#
# [1000 rows x 12 columns]

# %%
len(df_binance_bnbusdt_5m), len(df_binance_bnbusdt_1m)
# Out:
# (1000, 1000)

# %% [markdown]
# ### Reading Rounds Data from Pancake Subgraph
# 🔗 Source: https://api.thegraph.com/subgraphs/name/pancakeswap/prediction-v2
#
# Method: `POST`
#
# Query:
#
# { query: "{ rounds(first: 1000 where: {position_not: null} orderBy: epoch,orderDirection:desc) {
#     id
#     epoch
#     position
#     failed
#     startAt
#     startBlock
#     startHash
#     lockAt
#     lockBlock
#     lockHash
#     lockPrice
#     lockRoundId
#     closeAt
#     closeBlock
#     closeHash
#     closePrice
#     closeRoundId
#     totalBets
#     totalAmount
#     bullBets
#     bullAmount
#     bearBets
#     bearAmount
#     }
# }", }

# %%
pancake_subgraph_url = 'https://api.thegraph.com/subgraphs/name/pancakeswap/prediction-v2'
pancake_rounds_query = '{"query": "{ rounds(first: 1000 where: {position_not: null} orderBy: epoch,orderDirection:desc) { id epoch position failed startAt startBlock startHash lockAt lockBlock lockHash lockPrice lockRoundId closeAt closeBlock closeHash closePrice closeRoundId totalBets totalAmount bullBets bullAmount bearBets bearAmount } }"}'

# %%
import requests
req_pancake_rounds = requests.post(url=pancake_subgraph_url, data=pancake_rounds_query)

# %%
req_pancake_rounds
# Out:
# <Response [200]>

# %%
json_pancake_rounds = req_pancake_rounds.json()

# %%
len(json_pancake_rounds["data"]["rounds"])
# Out:
# 1000

# %%
df_pancake_rounds = pd.DataFrame.from_dict(json_pancake_rounds["data"]["rounds"])

# %%
df_pancake_rounds
# Out:
#          id   epoch position  failed     startAt startBlock  \
# 0    111219  111219     Bear   False  1665479998   22079890
# 1    111218  111218     Bull   False  1665479687   22079787
# 2    111217  111217     Bear   False  1665479377   22079693
# 3    111216  111216     Bull   False  1665479070   22079591
# 4    111215  111215     Bear   False  1665478764   22079489
# ..      ...     ...      ...     ...         ...        ...
# 995  110224  110224     Bear   False  1665172295   21978365
# 996  110223  110223     Bear   False  1665171986   21978262
# 997  110222  110222     Bull   False  1665171677   21978159
# 998  110221  110221     Bear   False  1665171368   21978056
# 999  110220  110220     Bull   False  1665171059   21977953
#
#                                              startHash      lockAt lockBlock  \
# 0    0x6232932572085f9505ff3fcc144003af78d6e33e133d...  1665480307  22079989
# 1    0xc93b9992fe1e0c14ed4102fe705cd7dbaf409f133e97...  1665479998  22079890
# 2    0xdcf5ba7470d1d523558b64ba08923d4cd3f6c07d0c79...  1665479687  22079787
# 3    0x335707601f3a5adc1dee11d5b579129fdadd6b40f308...  1665479377  22079693
# 4    0x4be16a8d7a29e73b855c0491d921aaf9ea226546bc32...  1665479070  22079591
# ..                                                 ...         ...       ...
# 995  0xf2301a7a96aecb68e29310c45e63fad7ecc2d9fbcba3...  1665172604  21978468
# 996  0xcc1ebb5b82e69a2bc272ba690eda35c2e287394f45d7...  1665172295  21978365
# 997  0x01d7238829ae28afff1ebeb6d4868292c4bb6088dab7...  1665171986  21978262
# 998  0x6b3f6b1da3c7813e70877b046db6056bd75c74d29028...  1665171677  21978159
# 999  0x1ab0333091c38f0e04657669a7d968e9e741eb5037d9...  1665171368  21978056
#
#                                               lockHash  ... closeBlock  \
# 0    0x274b83aa607395e96830e877b238bb6eb9300c440174...  ...   22080078
# 1    0x6232932572085f9505ff3fcc144003af78d6e33e133d...  ...   22079989
# 2    0xc93b9992fe1e0c14ed4102fe705cd7dbaf409f133e97...  ...   22079890
# 3    0xdcf5ba7470d1d523558b64ba08923d4cd3f6c07d0c79...  ...   22079787
# 4    0x335707601f3a5adc1dee11d5b579129fdadd6b40f308...  ...   22079693
# ..                                                 ...  ...        ...
# 995  0x840dd72c6cdf696fb2cbe5ff2f9e0b2a8e761dc3a59f...  ...   21978570
# 996  0xf2301a7a96aecb68e29310c45e63fad7ecc2d9fbcba3...  ...   21978468
# 997  0xcc1ebb5b82e69a2bc272ba690eda35c2e287394f45d7...  ...   21978365
# 998  0x01d7238829ae28afff1ebeb6d4868292c4bb6088dab7...  ...   21978262
# 999  0x6b3f6b1da3c7813e70877b046db6056bd75c74d29028...  ...   21978159
#
#                                              closeHash    closePrice  \
# 0    0xcfde4a4e49451b19b7202f1c2cf98035d1e56f52b792...        271.12
# 1    0x274b83aa607395e96830e877b238bb6eb9300c440174...        271.27
# 2    0x6232932572085f9505ff3fcc144003af78d6e33e133d...  271.20472633
# 3    0xc93b9992fe1e0c14ed4102fe705cd7dbaf409f133e97...  271.32821308
# 4    0xdcf5ba7470d1d523558b64ba08923d4cd3f6c07d0c79...   271.2288905
# ..                                                 ...           ...
# 995  0xd9fec399fbd554e8cb48ed3a4750fd2489cc756f1115...        282.68
# 996  0x840dd72c6cdf696fb2cbe5ff2f9e0b2a8e761dc3a59f...        282.82
# 997  0xf2301a7a96aecb68e29310c45e63fad7ecc2d9fbcba3...  282.97112138
# 998  0xcc1ebb5b82e69a2bc272ba690eda35c2e287394f45d7...  282.82124657
# 999  0x01d7238829ae28afff1ebeb6d4868292c4bb6088dab7...        282.95
#
#              closeRoundId totalBets            totalAmount bullBets  \
# 0    18446744073711487238        69  11.617474694649916685       28
# 1    18446744073711487223        62   8.416611169459303929       33
# 2    18446744073711487209        75  13.095194413913578542       33
# 3    18446744073711487193        67   8.035283259163454267       44
# 4    18446744073711487180        72  13.995362241459809407       34
# ..                    ...       ...                    ...      ...
# 995  18446744073711472970        75  12.767571904838288889       47
# 996  18446744073711472954        83  15.249814974767527573       46
# 997  18446744073711472942        80  12.110001770639958608       37
# 998  18446744073711472929        77  11.441225720861846015       41
# 999  18446744073711472915        78  15.757578916060213907       45
#
#                bullAmount bearBets            bearAmount
# 0    5.764499583177905874       41  5.852975111472010811
# 1    4.615358024543494943       29  3.801253144915808986
# 2    5.508284749823870342       42    7.5869096640897082
# 3      5.5116926599229639       23  2.523590599240490367
# 4    6.510416737770490733       38  7.484945503689318674
# ..                    ...      ...                   ...
# 995  7.605659772342266617       28  5.161912132496022272
# 996  8.715046598751494612       37  6.534768376016032961
# 997  3.459484654724987427       43  8.650517115914971181
# 998  6.186305744260915925       36   5.25491997660093009
# 999  6.374889234473125298       33  9.382689681587088609
#
# [1000 rows x 23 columns]

# %%
# Create a key-column to join DataFrames
df_binance_bnbusdt_5m["timestamp_key"] = pd.to_datetime(df_binance_bnbusdt_5m["5m_close_time"], unit='ms')
df_binance_bnbusdt_1m["timestamp_key"] = pd.to_datetime(df_binance_bnbusdt_1m["1m_close_time"], unit='ms')
df_pancake_rounds["timestamp_key"] = pd.to_datetime(df_pancake_rounds["closeAt"], unit='s')

# Sort by join key
df_binance_bnbusdt_5m.sort_values('timestamp_key', inplace=True)
df_binance_bnbusdt_1m.sort_values('timestamp_key', inplace=True)
df_pancake_rounds.sort_values('timestamp_key', inplace=True)

# %%
# Join Dataframes
df_joined = pd.merge_asof(df_binance_bnbusdt_5m, df_pancake_rounds, on='timestamp_key',direction = 'nearest', tolerance=pd.Timedelta("5 min"))
df_joined
# Out:
#       5m_open_time  5m_open_price  5m_high_price  5m_low_price  \
# 0    1665180900000          282.8          283.1         282.7
# 1    1665181200000          283.0          283.0         282.8
# 2    1665181500000          282.9          283.1         282.9
# 3    1665181800000          283.0          283.0         282.6
# 4    1665182100000          283.0          283.0         282.9
# ..             ...            ...            ...           ...
# 995  1665479400000          271.2          271.5         271.2
# 996  1665479700000          271.4          271.4         271.2
# 997  1665480000000          271.3          271.4         271.1
# 998  1665480300000          271.3          271.3         271.1
# 999  1665480600000          271.1          271.2         271.1
#
#      5m_close_price  5m_volume  5m_close_time  5m_quote_asset_volume  \
# 0             283.0    494.876  1665181199999            139990.3954
# 1             282.9    332.464  1665181499999             94055.5657
# 2             283.0    449.398  1665181799999            127208.4404
# 3             283.0    440.907  1665182099999            124694.9276
# 4             283.0     63.196  1665182399999             17881.8360
# ..              ...        ...            ...                    ...
# 995           271.3   1249.660  1665479699999            339137.5645
# 996           271.2    399.490  1665479999999            108388.0791
# 997           271.3    434.822  1665480299999            117934.2470
# 998           271.2    144.178  1665480599999             39098.4342
# 999           271.2    171.272  1665480899999             46443.5707
#
#      5m_number_of_trades  5m_taker_buy_base_asset_volume  ...  closeBlock  \
# 0                    256                         369.934  ...    21981342
# 1                    239                          89.685  ...    21981445
# 2                    263                         353.039  ...    21981549
# 3                    354                         207.919  ...    21981652
# 4                    199                          36.876  ...    21981755
# ..                   ...                             ...  ...         ...
# 995                  509                         897.984  ...    22079787
# 996                  433                         222.942  ...    22079890
# 997                  459                         161.427  ...    22079989
# 998                  292                          59.500  ...    22080078
# 999                  150                         117.315  ...    22080078
#
#                                              closeHash    closePrice  \
# 0    0x25e77318e259a662803c7fd241c7e1459c3d8b1d3627...  282.95534763
# 1    0x7e8cdbf759acf53ffd3a9f57ca553eda67116e08540e...        283.02
# 2    0xcf00e2dc67bd4b282da9479b317a7c43c6ffc227d65b...  282.88231916
# 3    0x78b7d62ddd73ada9be1240aa33fc54356991313dfa25...  282.99778406
# 4    0x2423e1559801582c06fc7290632da8ed83b972a65603...        282.99
# ..                                                 ...           ...
# 995  0xc93b9992fe1e0c14ed4102fe705cd7dbaf409f133e97...  271.32821308
# 996  0x6232932572085f9505ff3fcc144003af78d6e33e133d...  271.20472633
# 997  0x274b83aa607395e96830e877b238bb6eb9300c440174...        271.27
# 998  0xcfde4a4e49451b19b7202f1c2cf98035d1e56f52b792...        271.12
# 999  0xcfde4a4e49451b19b7202f1c2cf98035d1e56f52b792...        271.12
#
#              closeRoundId totalBets            totalAmount  bullBets  \
# 0    18446744073711473363        60   9.676199588684230193        27
# 1    18446744073711473379        88   25.43877191487197612        35
# 2    18446744073711473392        74  12.487243475462812124        58
# 3    18446744073711473407        84  14.292712137398385528        39
# 4    18446744073711473421        72  10.805704917508345809        41
# ..                    ...       ...                    ...       ...
# 995  18446744073711487193        67   8.035283259163454267        44
# 996  18446744073711487209        75  13.095194413913578542        33
# 997  18446744073711487223        62   8.416611169459303929        33
# 998  18446744073711487238        69  11.617474694649916685        28
# 999  18446744073711487238        69  11.617474694649916685        28
#
#                 bullAmount bearBets             bearAmount
# 0     5.339867558847011132       33   4.336332029837219061
# 1    10.911159159800761734       53  14.527612755071214386
# 2     7.388240146787759837       16   5.099003328675052287
# 3     4.119315005210344927       45  10.173397132188040601
# 4     4.599908183602754721       31   6.205796733905591088
# ..                     ...      ...                    ...
# 995     5.5116926599229639       23   2.523590599240490367
# 996   5.508284749823870342       42     7.5869096640897082
# 997   4.615358024543494943       29   3.801253144915808986
# 998   5.764499583177905874       41   5.852975111472010811
# 999   5.764499583177905874       41   5.852975111472010811
#
# [1000 rows x 36 columns]
